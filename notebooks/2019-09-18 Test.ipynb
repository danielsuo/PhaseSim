# %%
from phasesim import *
# Out:
# /home/dsuo/miniconda3/lib/python3.6/site-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))

# %%
parse_heartbeats("data/test.txt")
# Out:
#     instructions    cycles  heartbeat_ipc  cumulative_ipc  hours  minutes  \
# 0        1000000    533601       1.874060        1.874060      0        0
# 1        2000000   1046321       1.950380        1.911460      0        0
# 2        3000003   1584709       1.857400        1.893090      0        0
# 3        4000001   2098715       1.945500        1.905930      0        0
# 4        5000000   2675092       1.734970        1.869090      0        0
# 5        6000000   3222376       1.827200        1.861980      0        0
# 6        7000001   3735121       1.950290        1.874100      0        0
# 7        8000003   4273433       1.857660        1.872030      0        0
# 8        9000001   4781503       1.968230        1.882250      0        0
# 9       10000003   5310698       1.889670        1.882990      0        0
# 10      11000000   6755854       0.691965        0.691965      0        0
# 11      12000000   8211075       0.687181        0.689564      0        0
# ...

# %%
parse_telemetry("data/test.txt", "CPIPhaseDetector", columns)
